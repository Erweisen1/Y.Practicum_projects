# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Инструкция-по-выполнению-проекта:" data-toc-modified-id="Инструкция-по-выполнению-проекта:-0.1">Инструкция по выполнению проекта:</a></span><ul class="toc-item"><li><span><a href="#Шаг-1.-Загрузите-данные-и-подготовьте-их-к-анализу" data-toc-modified-id="Шаг-1.-Загрузите-данные-и-подготовьте-их-к-анализу-0.1.1">Шаг 1. Загрузите данные и подготовьте их к анализу</a></span></li><li><span><a href="#Шаг-2.-Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Шаг-2.-Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-0.1.2">Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span></li><li><span><a href="#Шаг-3.-Проведите-исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Проведите-исследовательский-анализ-данных-0.1.3">Шаг 3. Проведите исследовательский анализ данных</a></span></li><li><span><a href="#Шаг-4.-Маркетинг" data-toc-modified-id="Шаг-4.-Маркетинг-0.1.4">Шаг 4. Маркетинг</a></span></li><li><span><a href="#Шаг-5.-Оцените-окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Шаг-5.-Оцените-окупаемость-рекламы-для-привлечения-пользователей-0.1.5">Шаг 5. Оцените окупаемость рекламы для привлечения пользователей</a></span></li><li><span><a href="#Шаг-6.-Напишите-выводы" data-toc-modified-id="Шаг-6.-Напишите-выводы-0.1.6">Шаг 6. Напишите выводы</a></span></li><li><span><a href="#Оформление:" data-toc-modified-id="Оформление:-0.1.7">Оформление:</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.1.8">Описание данных</a></span></li><li><span><a href="#Проанализируйте-общую-окупаемость-рекламы" data-toc-modified-id="Проанализируйте-общую-окупаемость-рекламы-0.1.9">Проанализируйте общую окупаемость рекламы</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам-0.1.10">Проанализируйте окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-странам-0.1.11">Проанализируйте окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-0.1.12">Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-окупаемости-рекламы-приложения-Procrastinate-Pro+" data-toc-modified-id="Анализ-окупаемости-рекламы-приложения-Procrastinate-Pro+-1">Анализ окупаемости рекламы приложения Procrastinate Pro+</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2">Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1">Вывод</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-3">Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Пользовательские-профили" data-toc-modified-id="Пользовательские-профили-4.1">Пользовательские профили</a></span></li><li><span><a href="#Определение-стран-пользователей" data-toc-modified-id="Определение-стран-пользователей-4.2">Определение стран пользователей</a></span></li><li><span><a href="#Определение-устройств-клиентов" data-toc-modified-id="Определение-устройств-клиентов-4.3">Определение устройств клиентов</a></span></li><li><span><a href="#Определение-рекламных-источников" data-toc-modified-id="Определение-рекламных-источников-4.4">Определение рекламных источников</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5">Вывод</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-5">Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-маркетинг" data-toc-modified-id="Расходы-на-маркетинг-5.1">Расходы на маркетинг</a></span></li><li><span><a href="#Стоимость-привлечения-клиента" data-toc-modified-id="Стоимость-привлечения-клиента-5.2">Стоимость привлечения клиента</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.3">Вывод</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-6">Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-6.1">Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-6.2">Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-6.3">Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Графики-конверсии-и-удержания" data-toc-modified-id="Графики-конверсии-и-удержания-6.4">Графики конверсии и удержания</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.5">Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7">Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Анализ окупаемости рекламы приложения Procrastinate Pro+
#
# **Цель:** Определить факторы, влияющие на привлечение пользователей, и дать рекомендации для рекламного отдела.
#
# **Описание данных:**
#
# Таблица `visits_log_short` (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session Start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# Таблица `orders_log_short` (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# Таблица `costs_short` (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %%
# Выгрузка необходимых библиотек
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Выгрузка массивов данных
df_visits = pd.read_csv('/datasets/visits_info_short.csv', parse_dates=['Session Start', 'Session End'])
df_orders = pd.read_csv('/datasets/orders_info_short.csv', parse_dates=['Event Dt'])
df_costs = pd.read_csv('/datasets/costs_info_short.csv', parse_dates=['dt'])

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# **Обработка df_visits:**

# %%
# Изучим информацию о посещениях сайта
display(df_visits.head())
df_visits.info()
print('\nКоличество дубликатов:', df_visits.duplicated().sum())
# Out:
#         User Id         Region   Device  Channel       Session Start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           Session End
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# User Id          309901 non-null int64
# Region           309901 non-null object
# Device           309901 non-null object
# Channel          309901 non-null object
# Session Start    309901 non-null datetime64[ns]
# Session End      309901 non-null datetime64[ns]
# ...

# %%
print('Исходные названия колонок:', df_visits.columns.to_list())
df_visits.columns = df_visits.columns.str.lower().str.replace(' ', '_')
print('Измененные названия колонок:', df_visits.columns.to_list())
# Out:
# Исходные названия колонок: ['User Id', 'Region', 'Device', 'Channel', 'Session Start', 'Session End']
# Измененные названия колонок: ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']

# %% [markdown]
# **Обработка df_orders:**

# %%
# Изучим информацию  о заказах
display(df_orders.head())
df_orders.info()
print('\nКоличество дубликатов:', df_orders.duplicated().sum())
# Out:
#         User Id            Event Dt  Revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# User Id     40212 non-null int64
# Event Dt    40212 non-null datetime64[ns]
# Revenue     40212 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
#
# Количество дубликатов: 0

# %%
print('Исходные названия колонок:', df_orders.columns.to_list())
df_orders.columns = df_orders.columns.str.lower().str.replace(' ', '_')
print('Измененные названия колонок:', df_orders.columns.to_list())
# Out:
# Исходные названия колонок: ['User Id', 'Event Dt', 'Revenue']
# Измененные названия колонок: ['user_id', 'event_dt', 'revenue']

# %%
display(df_orders.describe())
# Out:
#             user_id       revenue
# count  4.021200e+04  40212.000000
# mean   4.990295e+11      5.370608
# std    2.860937e+11      3.454208
# min    5.993260e+05      4.990000
# 25%    2.511324e+11      4.990000
# 50%    4.982840e+11      4.990000
# 75%    7.433327e+11      4.990000
# max    9.998954e+11     49.990000

# %% [markdown]
# **Обработка df_costs:**

# %%
# Изучим информацию о затратах на маркетинг
display(df_costs.head())
df_costs.info()
print('\nКоличество дубликатов:', df_costs.duplicated().sum())
# Out:
#           dt   Channel  costs
# 0 2019-05-01  FaceBoom  113.3
# 1 2019-05-02  FaceBoom   78.1
# 2 2019-05-03  FaceBoom   85.8
# 3 2019-05-04  FaceBoom  136.4
# 4 2019-05-05  FaceBoom  122.1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null datetime64[ns]
# Channel    1800 non-null object
# costs      1800 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB
#
# Количество дубликатов: 0

# %%
print('Исходные названия колонок:', df_costs.columns.to_list())
df_costs.columns = df_costs.columns.str.lower().str.replace(' ', '_')
print('Измененные названия колонок:', df_costs.columns.to_list())
# Out:
# Исходные названия колонок: ['dt', 'Channel', 'costs']
# Измененные названия колонок: ['dt', 'channel', 'costs']

# %%
display(df_costs['costs'].describe())
df_costs['costs'].plot()
plt.show()
# Out:
# count    1800.000000
# mean       58.609611
# std       107.740223
# min         0.800000
# 25%         6.495000
# 50%        12.285000
# 75%        33.600000
# max       630.000000
# Name: costs, dtype: float64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Получены следующие массивы данных:
# `df_visits` - содержит уникальный идентификатор пользователя, страну пользователя, тип устройства, идентификатор источника перехода, дата и время начала сессии, дата и время окончания сессии.
# `df_orders` - содержит уникальный идентификатор пользователя, дата и время покупки, сумма заказа.
# `df_costs` - содержит идентификатор рекламного источника, дату проведения рекламной кампании, расходы на эту кампанию.
#
# Были предоставлены качественные данные без пропусков и дубликатов, так же  не были обнаружены аномалии в виде отрицательных и нулевых значений в таблицах с информацией о заказах и расходах на рекламу, поэтому для предобработки потребовалось лишь изменить названия колонок и поменять тип в столбцах с датами.

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Функция для расчета удержания:

# %%
def get_retention(profiles, sessions, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
    # решаем какие столбцы оставим для группировки удержания, столбец признака платящего пользователя остается всегда
    dimensions = ['payer'] + dimensions
    
    # оттсекаем всех пользователей, которые не могли "дожить" до нужного горизонта 
    # (присоединились позже чем observation_date - horizon)
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # формируем массив сырых данных
    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    # функция группировки по нужному набору измерений
    def group_by_dimensions(df, dims, horizon_days):     
        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')     # строим "треугольную таблицу" 
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) # определяем размеры когорт
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)                                   # присоединяем размеры когорт к треугольной таблице
        result = result.div(result['cohort_size'], axis = 0)                                                     # делим каждый из столбцов на размер когорты - расчитываем % удержания (retention rate)
        result = result[['cohort_size'] + list(range(horizon_days))]                                             # оставляем только наблюдения до нужного горизонта и столбец размеров когорт
        result['cohort_size'] = cohort_sizes                                                                     # пересприсваиваем столбец размеров когорт, ведь во время деления он превратился в 1
        return result
    
    # расчитываем удержание 
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    # рассчитываем удержание по всем параметрам + дата
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    # возвращаем и таблицы удержания и сырые данные (чтобы в случае чего можно было в них покопаться при отладке)
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция для расчета конверсии:

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу конверсии
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        # считаем сумму с накоплением для каждой строки
        result = result.fillna(0).cumsum(axis = 1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # добавляем размеры когорт в таблицу конверсии
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция для расчета LTV и ROI:

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Функции для визуализации:

# %%
# функция для сглаживания датафрейма
def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
def plot_retention(retention, retention_history, horizon, window=3):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в четвёртой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=3):

    plt.figure(figsize=(20, 10))

    ltv = ltv.drop(columns=['cohort_size'])
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]
    cac_history = roi_history[['cac']]
    roi = roi.drop(columns=['cohort_size', 'cac'])
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
def plot_conversion(conversion, conversion_history, horizon, window=3):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Пользовательские профили

# %% [markdown]
# Построим профили пользователей. Определим минимальную и максимальную дату привлечения пользователей.

# %%
def get_profiles(visits, orders, costs):
 
    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )
 
    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
 
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
 
    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
 
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    
    costs['dt'] = costs['dt'].dt.date
    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')
 
    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']
 
 
    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
 
    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
 
    return profiles

profiles = get_profiles(df_visits, df_orders, df_costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %%
print('Минимальная дата привлечения:', profiles['first_ts'].dt.date.min())
print('Максимальная дата привлечения:', profiles['first_ts'].dt.date.max())
# Out:
# Минимальная дата привлечения: 2019-05-01
# Максимальная дата привлечения: 2019-10-27

# %% [markdown]
# ### Определение стран пользователей

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.

# %%
print('Количество пользователей из каждой страны:\n',
      profiles.groupby('region').agg({'user_id': 'nunique'}).sort_values(by='user_id'))
# Out:
# Количество пользователей из каждой страны:
#                 user_id
# region
# Germany          14981
# France           17450
# UK               17575
# United States   100002

# %% [markdown]
# Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
payer_region_profiles = profiles.groupby('region').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
payer_region_profiles.columns = ['total', 'payers', 'percentage, %']
print('Количество платящих пользователей в каждой стране:\n',
      payer_region_profiles.sort_values(by='payers'))
# Out:
# Количество платящих пользователей в каждой стране:
#                  total  payers  percentage, %
# region
# Germany         14981   616.0       0.041119
# France          17450   663.0       0.037994
# UK              17575   700.0       0.039829
# United States  100002  6902.0       0.069019

# %% [markdown]
# ### Определение устройств клиентов

# %% [markdown]
# Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.

# %%
print('Количество пользователей на каждое устройство:\n',
      profiles.groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id'))
# Out:
# Количество пользователей на каждое устройство:
#           user_id
# device
# Mac        30042
# PC         30455
# Android    35032
# iPhone     54479

# %% [markdown]
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
payer_device_profiles = profiles.groupby('device').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
payer_device_profiles.columns = ['total', 'payers', 'percentage, %']
print('Количество платящих пользователей на каждое устройство:\n',
      payer_device_profiles.sort_values(by='payers', ascending=False))
# Out:
# Количество платящих пользователей на каждое устройство:
#           total  payers  percentage, %
# device
# iPhone   54479  3382.0       0.062079
# Android  35032  2050.0       0.058518
# Mac      30042  1912.0       0.063644
# PC       30455  1537.0       0.050468

# %% [markdown]
# ### Определение рекламных источников

# %% [markdown]
# Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.

# %%
print('Количество пользователей из каждого рекламного источника:\n',
      profiles.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id'))
# Out:
# Количество пользователей из каждого рекламного источника:
#                      user_id
# channel
# lambdaMediaAds         2149
# AdNonSense             3880
# YRabbit                4312
# MediaTornado           4364
# RocketSuperAds         4448
# LeapBob                8553
# WahooNetBanner         8553
# OppleCreativeMedia     8605
# TipTop                19561
# FaceBoom              29144
# organic               56439

# %% [markdown]
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
payer_channel_profiles = profiles.groupby('channel').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
payer_channel_profiles.columns = ['total', 'payers', 'percentage, %']
print('Количество платящих пользователей из каждого рекламного источника:\n', 
      payer_channel_profiles.sort_values(by='payers'))
# Out:
# Количество платящих пользователей из каждого рекламного источника:
#                      total  payers  percentage, %
# channel
# MediaTornado         4364   156.0       0.035747
# YRabbit              4312   165.0       0.038265
# lambdaMediaAds       2149   225.0       0.104700
# OppleCreativeMedia   8605   233.0       0.027077
# LeapBob              8553   262.0       0.030633
# RocketSuperAds       4448   352.0       0.079137
# AdNonSense           3880   440.0       0.113402
# WahooNetBanner       8553   453.0       0.052964
# organic             56439  1160.0       0.020553
# TipTop              19561  1878.0       0.096007
# FaceBoom            29144  3557.0       0.122049

# %% [markdown]
# ### Вывод

# %% [markdown]
# Больше всего пользователей пришло в приложение из Соединенных Штатов - `61829` человек, наименьшее количество пользователей - из Германии - всего `9528`. Распределение платящих пользователей совпадает с вышеописанным - `6108` из Соединенных Штатов и `490` из Германии.
#
# Наибольшей популярностью среди клиентов пользуются айфоны - их выбирают `33882` человек, наименьшей - макбуки, их предпочитают `18693` человек. `2972` платящих пользователя так же выбирают айфоны, в то время как наименьшая популярность у компьютеров - их предпочитают `1294`пользователей.
#
# Что касаемо рекламных источников, наибольшее количество пользователей - `56439` - органические, а затем уже идет FaceBoom с `29144` привлеченными клиентами. Самая большая часть платящих пользователей приходила оттуда же - `3557` человек из FaceBoom, когда как наименьшая - из `MediaTornado` - всего `156` человек.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Расходы на маркетинг

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг. Выясним, как траты распределены по источникам. Визуализируем изменения метрик во времени.

# %%
print('Всего на рекламу было потрачено:',
     round(df_costs['costs'].sum(), 2))
# Out:
# Всего на рекламу было потрачено: 105497.3

# %%
channel_costs = df_costs.groupby('channel').sum().reset_index()
channel_costs['percentage'] = round(channel_costs['costs'] * 100 / df_costs['costs'].sum(), 2)
channel_costs = channel_costs.sort_values(by='percentage')
print('На каждый источник было потрачено:\n')
channel_costs
# Out:
# На каждый источник было потрачено:
#               channel     costs  percentage
# 3        MediaTornado    954.48        0.90
# 8             YRabbit    944.22        0.90
# 9      lambdaMediaAds   1557.60        1.48
# 2             LeapBob   1797.60        1.70
# 5      RocketSuperAds   1833.00        1.74
# 4  OppleCreativeMedia   2151.25        2.04
# 0          AdNonSense   3911.25        3.71
# 7      WahooNetBanner   5151.00        4.88
# 1            FaceBoom  32445.60       30.75
# 6              TipTop  54751.30       51.90

# %%
plt.figure(figsize=(10, 4))
ax = sns.barplot(x='channel', y='percentage', data=channel_costs)
ax.set_xticklabels(ax.get_xticklabels(), rotation=80)
plt.title('Распределение затрат на рекламу')
ax.set_xlabel('Источник')
ax.set_ylabel('Часть, %')
plt.show()

# %%
df_costs['dt_month'] = df_costs['dt'].astype('datetime64[M]')
months_costs = df_costs.groupby('dt_month')['costs'].sum().reset_index()
print('Было потрачено в месяце:\n ', months_costs)
# Out:
# Было потрачено в месяце:
#       dt_month      costs
# 0 2019-05-01   9978.570
# 1 2019-06-01  15090.045
# 2 2019-07-01  16447.060
# 3 2019-08-01  20657.870
# 4 2019-09-01  22441.340
# 5 2019-10-01  20882.415

# %%
months_costs.plot(y='costs', x='dt_month', grid=True)
plt.title('Расходы помесячно')
plt.xlabel('Месяц')
plt.ylabel('Затраты')
plt.show()

# %%
channel_months_costs = df_costs.pivot_table(index='dt_month', columns='channel', values='costs', aggfunc='sum')
channel_months_costs.plot(figsize=(15,8))
plt.title('Распределение расходов помесячно')
plt.xlabel('Месяц')
plt.ylabel('Затраты')
plt.show()

# %% [markdown]
# ### Стоимость привлечения клиента

# %% [markdown]
# Узнаем, сколько в среднем стоило привлечение одного пользователя из каждого источника. Рассчитаем средний CAC на одного пользователя для всего проекта и для каждого источника трафика без учета органических пользователей.

# %%
count_customers = profiles[['channel', 'user_id']].groupby('channel').count()
sum_costs = df_costs.groupby('channel').sum()

cac = count_customers.merge(sum_costs, on='channel').fillna(0).reset_index()
cac.columns = ['channel', 'customers', 'costs']
cac['cac'] = round(cac['costs'] / cac['customers'], 2)
cac = cac.sort_values(by='cac')
cac
# Out:
#               channel  customers     costs   cac
# 2             LeapBob       8553   1797.60  0.21
# 3        MediaTornado       4364    954.48  0.22
# 8             YRabbit       4312    944.22  0.22
# 4  OppleCreativeMedia       8605   2151.25  0.25
# 5      RocketSuperAds       4448   1833.00  0.41
# 7      WahooNetBanner       8553   5151.00  0.60
# 9      lambdaMediaAds       2149   1557.60  0.72
# 0          AdNonSense       3880   3911.25  1.01
# 1            FaceBoom      29144  32445.60  1.11
# 6              TipTop      19561  54751.30  2.80

# %%
plt.figure(figsize=(10, 4))
ax = sns.barplot(x='channel', y='cac', data=cac)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.title('Стоимость привлечения клиента')
ax.set_xlabel('Источник')
ax.set_ylabel('Стоимость')
plt.show()

# %%
print('Стоимость привлечения клиента по всему проекту:', 
      round(cac['costs'].sum() / cac['customers'].sum(), 2))
# Out:
# Стоимость привлечения клиента по всему проекту: 1.13

# %% [markdown]
# ### Вывод

# %% [markdown]
# Общие затраты на всю рекламу составили `105497.3`. Наибольшие расходы ушли на TipTop - они составили `51.9%` или `54751.3`, следом идет FaceBoom c `30.75%`, самые затратные рекламные кампании проводились в сентябре.
#
# Так же наиболее высокая стоимость привлечения клиентов у TipTop - `2.79` и у FaceBoom - `1.113`, что выше средней стоимости привлечения по всему проекту, которая составляет `1.127`.

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# Используя графики LTV, ROI и CAC, проанализируем окупаемость рекламы. Считаем, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.

# %% [markdown]
# ### Общая окупаемость рекламы
#
# Проанализируем общую окупаемость рекламы. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
profiles = profiles.query('channel != "organic"')

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles, df_orders, datetime(2019, 11, 1).date(), 14
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %% [markdown]
# **Вывод:**
#
# * LTV растет с увеличением количества дней
# * Стоимость привлечения пользователей увеличивается в течение полугода
# * Несмотря на то, что привлекать пользователей становится дороже, ROI падает и к июню становится ниже уровня окупаемости.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам
#
# Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles, df_orders, datetime(2019, 11, 1).date(), 14, dimensions=['channel']
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %% [markdown]
# **Вывод:**
#
# * Лидер по LTV - преимущественно `lambdaMediaAs`.
# * С точки зрения окупаемости, или ROI, лидирует `YRabbit`, а `TipTop` наиболее убыточный рекламный источник
# * По самой высокой стоимости привлечения пользователей с большим отрывом идет `TipTop`, а следом по убыванию `FaceBoom` и `AdNonSense`.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам
#
# Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles, df_orders, datetime(2019, 11, 1).date(), 14, dimensions=['region']
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %% [markdown]
# **Вывод:**
#
# * Лидер по LTV - преимущественно `United States`, следом идет `UK`.
# * С точки зрения окупаемости, или ROI, лидируют `UK`, `Germany` и `France`. Для пользователей из `United States` ничего не окупается.
# * По самой высокой стоимости привлечения пользователей с большим отрывом идет `UnitedStates`, а стоимость привлечения клиентов из остальных регионов примерно одинакова.

# %% [markdown]
# ### Графики конверсии и удержания
#
# Построим и изучим графики конверсии и удержания с разбивкой по устройствам:

# %%
retention_raw, retention, retention_history = get_retention(
    profiles, df_visits, datetime(2019, 11, 1).date(), 14, dimensions = ['device']
)

plot_retention(retention, retention_history, 14)

# %% [markdown]
# **Вывод:**
#
# Самое высокое удержание у платящих пользователей, которые пользуются `PC`, затем идет `Android`. А у неплатящих клиентов - те, кто пользуется `Mac`.

# %% [markdown]
# Построим и изучим графики конверсии и удержания с разбивкой по странам.

# %%
retention_raw, retention, retention_history = get_retention(
    profiles, df_visits, datetime(2019, 11, 1).date(), 14, dimensions = ['region']
)

plot_retention(retention, retention_history, 14)

# %% [markdown]
# **Вывод:**
#
# Самое высокое удержание у платящих пользователей из `UK`, `Germany` и `France`. Наименьшее - у клиентов из `United States`.
# А неплатящих пользователей лучше всего получается удержать из `United States`.

# %% [markdown]
# Построим и изучим графики конверсии и удержания с разбивкой по рекламным каналам.

# %%
retention_raw, retention, retention_history = get_retention(
    profiles, df_visits, datetime(2019, 11, 1).date(), 14, dimensions = ['channel']
)

plot_retention(retention, retention_history, 14)

# %% [markdown]
# **Вывод:**
#
# Самое высокое удержание у платящих пользователей, которые были привлечены рекламным источником `WahooNetBanner`, когда как для неплатящих это `LeapBob`.

# %% [markdown]
# **Оценка окупаемости рекламы в `United States`:**

# %% [markdown]
# Построим графики с разбивкой по рекламным источникам в рамках `United States`:

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles.query('region == "United States"'), df_orders, datetime(2019, 11, 1).date(), 14, dimensions=['channel']
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %% [markdown]
# Построим графики с разбивкой по рекламным источникам в рамках `United States`:

# %%
retention_raw, retention, retention_history = get_retention(
    profiles.query('region == "United States"'), df_visits.query('region == "United States"'),
    datetime(2019, 11, 1).date(), 14, dimensions = ['channel']
)

plot_retention(retention, retention_history, 14)

# %% [markdown]
# С удержанием платящих пользователей из Америки хуже всего справляется `FaceBoom`, при том что стоимость привлечения клиентов из этого источника находится на втором месте по дороговизне после `TipTop`.

# %% [markdown]
# ### Вывод

# %% [markdown]
# * В целом, реклама слабо окупается. На снижение окупаемости рекламы могут влиять устройста `iPhone`, страна `United States` и такие каналы, как `TipTop` и `FaceBoom` с высокой стоимостью привлечения.
# * Возможно, эти проблемы связаны с тем, что основная аудитория `TipTop` и `FaceBoom` в принципе не заинтересована в приложении, а на устройствах `iPhone` может долго загружаться приложение или выдавать ошибку.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# * Причина неэффективности привлечения клиентов в том, что средства на рекламу идут в дорогостоящие, но при этом малозавлекающие рекламные источники, такие как `TipTop` и `FaceBoom` . Пользователи этих сервисов в основном не заинтересованы в приложении.
#
# Рекомендации маркетологам:
#
# * Закрыть рекламные кампании в вышеперечисленных сервисах
# * Привлечь больше средств на продвижение через такие рекламные каналы, как `lambdaMediaAs` и `YRabbit`
# * Обратить внимание на работу мобильного приложения для устройств `iPhone` и исправить возможные ошибки, которые могут приводить к дискомфорту при использовании.
